# %%
"""Offset and UPDRS correlation."""
# %load_ext autoreload
# %autoreload 2
from plot_settings import *
from analysis_settings import *
from os.path import join
from scripts.utils_plot import (_patient_symptoms, _patient_demographics, _patient_recording_and_leads,
                                _dataset_dbs_models, _patient_sample_size, _dataset_dbs_models_leads,
                                _dataset_comparison, _dataset_comparison_divided, _patient_symptoms_flat)

# %%
ch_choice = 'ch_dist_sweet'
dataframes = get_dfs(ch_choice)
df = dataframes['df']
# Out:
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/notebooks/analysis_settings.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['sub_hemi_cond'] = df.sub_hemi + '_' + df.cond
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/notebooks/analysis_settings.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pivot['UPDRS_exists'] = pivot.UPDRS_bradyrigid_contra.notna()
# ...

# %%
save_dir1 = join(SAVE_DIR, f"Figure1")

# %% [markdown]
# ### Single row

# %%
_dataset_comparison(df, save=True, save_dir=save_dir1)
# Out:
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1696: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Pre', 'Post'])
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1721: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub_gender['patient_sex'] = df_sub_gender['patient_sex'].map({'male': 'M', 'female': 'F'})

# %%
_dataset_comparison_divided(df, save=True, save_dir=save_dir1)
# Out:
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1839: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Pre', 'Post'])
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1874: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub_gender['patient_sex'] = df_sub_gender['patient_sex'].map({'male': 'M', 'female': 'F'})

# %%
# Attention: Sample size refers to channel_choice specified in analysis_settings.py
_patient_sample_size(df, save=True, save_dir=save_dir1)

# %%
# _patient_symptoms(df, save=True, save_dir=save_dir1, conds=['off'], show_yticks=False)

# %%
# _patient_demographics(df, save=True, save_dir=save_dir1, show_yticks=False)

# %%
# _patient_recording_and_leads(df, save=True, save_dir=save_dir1)

# %%
_dataset_dbs_models_leads(df, save=True, save_dir=save_dir1)
# Out:
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1569: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df.DBS_directional, 'ch_dir'] = 'Yes'
# /Users/moritzgerster/Library/CloudStorage/Dropbox/Code/STN_broadband_power/scripts/utils_plot.py:1609: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().remove()

# %%
# Directional leads
# _dataset_lead_directionality(df, save=False)

# %% [markdown]
# # Supplemental Material

# %%
# _patient_symptoms(df, save=True, save_dir=save_dir1, conds=['off', 'on', 'offon_abs'])

# %%
_patient_symptoms_flat(df, save=True, save_dir=save_dir1, conds=['off'])
_patient_symptoms_flat(df, save=True, save_dir=save_dir1, conds=['on'])
_patient_symptoms_flat(df, save=True, save_dir=save_dir1, conds=['offon_abs'])

# %%
# DBS models
# _dataset_dbs_models(df, save_dir=save_dir_supp, save=True)
